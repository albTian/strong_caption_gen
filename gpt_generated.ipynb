# %%
import pandas as pd

# Load the CSV file
strong_data = pd.read_csv('strong_w_kg.csv')

strong_data['Units'] = 'lbs'

# Show the first few rows of the data
strong_data.head()
# Out:
#                   Date     Workout Name Duration             Exercise Name  \
# 0  2021-07-07 18:35:21  Push - Shoulder      31m  Overhead Press (Barbell)
# 1  2021-07-07 18:35:21  Push - Shoulder      31m  Overhead Press (Barbell)
# 2  2021-07-07 18:35:21  Push - Shoulder      31m  Overhead Press (Barbell)
# 3  2021-07-07 18:35:21  Push - Shoulder      31m  Overhead Press (Barbell)
# 4  2021-07-07 18:35:21  Push - Shoulder      31m     Bench Press (Barbell)
#
#    Set Order     Weight  Reps  Distance  Seconds Notes Workout Notes  RPE  \
# 0          1  52.163123     4       0.0        0   NaN           NaN  NaN
# 1          2  52.163123     4       0.0        0   NaN           NaN  NaN
# 2          3  52.163123     4       0.0        0   NaN           NaN  NaN
# 3          4  52.163123     3       0.0        0   NaN           NaN  NaN
# 4          1  61.234970    10       0.0        0   NaN           NaN  NaN
#
#   Units
# 0   lbs
# 1   lbs
# 2   lbs
# 3   lbs
# 4   lbs

# %%
print("dog")
# Out:
# dog
